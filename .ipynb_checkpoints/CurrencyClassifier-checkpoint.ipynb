# %%
import numpy as np
import os
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

# %%
plt.style.use("ggplot")
# %matplotlib inline

# %%
main_train_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/")
main_test_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Test/")

print(main_train_dir)
print(main_test_dir)
# Out:
# C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/
# C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Test/

# %%
two_thousand_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/2Thousandnote/")
five_hundered_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/5Hundrednote/")
two_hundered_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/2Hundrednote/")
one_hundered_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/1Hundrednote/")
fifty_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/Fiftynote/")
twenty_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/Twentynote/")
ten_dir = os.path.join(r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset/Train/Tennote/")

# %%
two_thousand_names = os.listdir(two_thousand_dir)
five_hundered_names = os.listdir(five_hundered_dir)
two_hundered_names = os.listdir(two_hundered_dir)
one_hundered_names = os.listdir(one_hundered_dir)
fifty_names = os.listdir(fifty_dir)
twenty_names = os.listdir(twenty_dir)
ten_names = os.listdir(ten_dir)


print(two_thousand_names[:10])
print(five_hundered_names[:10])
print(two_hundered_names[:10])
print(one_hundered_names[:10])
print(fifty_names[:10])
print(twenty_names[:10])
print(ten_names[:10])
# Out:
# ['1.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpg', '16.jpg', '17.jpg', '19.jpg', '2.jpg', '20.jpg']
# ['12.jpg', '13.jpg', '15.jpg', '16.jpg', '18.jpg', '19.jpg', '2.jpg', '20.jpg', '21.jpg', '22.jpg']
# ['1.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpg', '17.jpg', '18.jpg', '19.jpg', '2.jpg', '20.jpg']
# ['1.jpg', '10.jpg', '11.jpg', '13.jpg', '18.jpg', '2.jpg', '20.jpg', '21.jpg', '22.jpg', '23.jpg']
# ['1.jpg', '11.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg']
# ['1.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpg', '15.jpg', '16.jpg', '17.jpg', '2.jpg', '20.jpg']
# ['1.jpg', '10.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg']

# %%
print(f"total training of 2Thousand Notes : {len(two_thousand_names)}")
print(f"total training of 5Hundered Notes : {len(five_hundered_names)}")
print(f"total training of 2Hundered Notes : {len(two_hundered_names)}")
print(f"total training of 1Hundered Notes: {len(one_hundered_names)}")
print(f"total training of 50Notes : {len(fifty_names)}")
print(f"total training of 20Notes : {len(twenty_names)}")
print(f"total training of 10Notes : {len(ten_names)}")
# Out:
# total training of 2Thousand Notes : 21
# total training of 5Hundered Notes : 22
# total training of 2Hundered Notes : 22
# total training of 1Hundered Notes: 22
# total training of 50Notes : 22
# total training of 20Notes : 22
# total training of 10Notes : 22

# %%
# parameters for graph we'll output images in a 4x4
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 2, nrows * 2)

pic_index += 8

two_thousand_pix = [os.path.join(two_thousand_dir, fname) 
                for fname in two_thousand_names[pic_index-8:pic_index]]

five_hundered_pix = [os.path.join(five_hundered_dir, fname) 
                for fname in five_hundered_names[pic_index-8:pic_index]]


for i, img in enumerate(two_thousand_pix + five_hundered_pix):
    sub_plot = plt.subplot(nrows, ncols, i + 1)
    sub_plot.axis("Off")
    img_read = mpimg.imread(img)
    plt.imshow(img_read)
    
plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation="relu", input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(32, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(7, activation="softmax")
])
# Out:
# C:\Users\HI\PycharmProjects\CRUIP\.venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 72, 72, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 36, 36, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 36, 36, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 34, 34, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 17, 17, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 15, 15, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 3136)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │         401,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 468,007 (1.79 MB)
#  Trainable params: 468,007 (1.79 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(main_train_dir,
                                                   batch_size=64,
                                                   target_size=(150,150),
                                                   class_mode="categorical")

validation_generator = validation_datagen.flow_from_directory(main_test_dir,
                                                             batch_size=16,
                                                              target_size=(150,150),
                                                             class_mode="categorical")
# Out:
# Found 153 images belonging to 7 classes.
# Found 42 images belonging to 7 classes.

# %%
history = model.fit(train_generator,   
                    epochs=100,
                    steps_per_epoch=len(train_generator),
                    verbose=1,
                    validation_data=validation_generator,
                    validation_steps=len(validation_generator))
# Out:
# Epoch 1/100
# C:\Users\HI\PycharmProjects\CRUIP\.venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 618ms/step - accuracy: 0.9224 - loss: 0.2110 - val_accuracy: 0.8095 - val_loss: 0.6163
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 600ms/step - accuracy: 0.9311 - loss: 0.1701 - val_accuracy: 0.6905 - val_loss: 0.7726
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 666ms/step - accuracy: 0.9277 - loss: 0.1642 - val_accuracy: 0.8333 - val_loss: 0.5398
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 793ms/step - accuracy: 0.9431 - loss: 0.1233 - val_accuracy: 0.8095 - val_loss: 0.5934
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 787ms/step - accuracy: 0.9809 - loss: 0.0883 - val_accuracy: 0.7857 - val_loss: 0.6204
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 635ms/step - accuracy: 0.9504 - loss: 0.1082 - val_accuracy: 0.7857 - val_loss: 0.6377
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 577ms/step - accuracy: 0.9737 - loss: 0.1025 - val_accuracy: 0.8095 - val_loss: 0.6785
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 592ms/step - accuracy: 0.9915 - loss: 0.0668 - val_accuracy: 0.7857 - val_loss: 0.7587
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 612ms/step - accuracy: 0.9735 - loss: 0.0819 - val_accuracy: 0.8333 - val_loss: 0.5892
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 643ms/step - accuracy: 0.9668 - loss: 0.0976 - val_accuracy: 0.7381 - val_loss: 0.6071
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 650ms/step - accuracy: 0.9839 - loss: 0.0570 - val_accuracy: 0.8333 - val_loss: 0.5125
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 615ms/step - accuracy: 0.9768 - loss: 0.0692 - val_accuracy: 0.8095 - val_loss: 0.5424
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 928ms/step - accuracy: 1.0000 - loss: 0.0389 - val_accuracy: 0.8095 - val_loss: 0.6088
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 925ms/step - accuracy: 0.9967 - loss: 0.0428 - val_accuracy: 0.8095 - val_loss: 0.4973
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 644ms/step - accuracy: 0.9909 - loss: 0.0326 - val_accuracy: 0.7857 - val_loss: 0.4850
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 626ms/step - accuracy: 0.9768 - loss: 0.0364 - val_accuracy: 0.8095 - val_loss: 0.6325
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 605ms/step - accuracy: 0.9948 - loss: 0.0249 - val_accuracy: 0.7619 - val_loss: 0.6367
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 688ms/step - accuracy: 0.9948 - loss: 0.0230 - val_accuracy: 0.8095 - val_loss: 0.4883
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 637ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8810 - val_loss: 0.6528
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 647ms/step - accuracy: 0.9909 - loss: 0.0328 - val_accuracy: 0.7619 - val_loss: 0.5700
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 645ms/step - accuracy: 0.9843 - loss: 0.0204 - val_accuracy: 0.7857 - val_loss: 0.6213
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 625ms/step - accuracy: 0.9900 - loss: 0.0214 - val_accuracy: 0.8095 - val_loss: 0.6662
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(len(acc))

plt.plot(epochs, acc, "r", label="Training Accuracy")
plt.plot(epochs, val_acc, "b", label="Validation Accuracy")

plt.legend()
plt.figure()

plt.plot(epochs, loss, "r", label="Training Loss")
plt.plot(epochs, val_loss, "b", label="Validation Loss")

plt.legend()
plt.show()

# %%
'''
path = r"C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset\Test\1Hundrednote/1.jpg"
img = image.load_img(path, target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
predict_x=model.predict(images) 
classes = np.argmax(predict_x,axis=1)



if classes[0] == 1:
    print(path + " is Two Thousand Rupees")
elif classes[0] == 2:
    print(path + " is Five Hundered Rupees")
elif classes[0] == 3:
    print(path + " is Two Hundered Rupees")
elif classes[0] == 4:
    print(path, + " is One Hundered Rupees")
elif classes[0] == 5:
    print(path + "is Fifty Rupees")
elif classes[0] == 6:
    print(path + " is Twenty Rupees")
else:
    print(path + " is Ten Rupees")
    
img = mpimg.imread(path)
plt.imshow(img)
plt.show()
'''
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C:\Users\HI\PycharmProjects\CRUIP\.venv\CurrencyPrediction\ModelGeneration\ModelDataset\Test\1Hundrednote/1.jpg is Ten Rupees
